# %%
import cx_Oracle

# %%
dns = cx_Oracle.makedsn('localhost', 1521, 'xe')

# %%
conn = cx_Oracle.connect('GWANGJU_B', 'DBDB', dns)

# %%
cursor = conn.cursor()

# %%
sql = "Select * From cart"
cursor.execute(sql)
# Out:
# <cx_Oracle.Cursor on <cx_Oracle.Connection to GWANGJU_B@(DESCRIPTION=(ADDRESS=(PROTOCOL=TCP)(HOST=localhost)(PORT=1521))(CONNECT_DATA=(SID=xe)))>>

# %%
rows=cursor.fetchall()
rows
"""
[{"mem_id":"a001","cart_no":"200504..", "cart_prod":값, "cart_qty":값},
{"mem_id":"a001","cart_no":"200504..", "cart_prod":값, "cart_qty":값},
{"mem_id":"a001","cart_no":"200504..", "cart_prod":값, "cart_qty":값},
...]
"""
# Out:
# '\n[{"mem_id":"a001","cart_no":"200504..", "cart_prod":값, "cart_qty":값},\n{"mem_id":"a001","cart_no":"200504..", "cart_prod":값, "cart_qty":값},\n{"mem_id":"a001","cart_no":"200504..", "cart_prod":값, "cart_qty":값},\n...]\n'

# %%
#컬럼명 조회
cols=cursor.description
cols
# Out:
# [('CART_MEMBER', <cx_Oracle.DbType DB_TYPE_VARCHAR>, 15, 15, None, None, 0),
#  ('CART_NO', <cx_Oracle.DbType DB_TYPE_CHAR>, 13, 13, None, None, 0),
#  ('CART_PROD', <cx_Oracle.DbType DB_TYPE_VARCHAR>, 10, 10, None, None, 0),
#  ('CART_QTY', <cx_Oracle.DbType DB_TYPE_NUMBER>, 9, None, 8, 0, 0)]

# %%
#컬럼명만 추출해 리스트에 담기
col=[]

for i in cols:
    col.append(i[0])

print(col)
# Out:
# ['CART_MEMBER', 'CART_NO', 'CART_PROD', 'CART_QTY']

# %%
# list_rows=[]
# list_row={}

# # for i in cols:
# #     print(i)
    
# for i in col:
#     list_row[i]=0
#     for row in rows:
#         for j in row:
#             list_row[i]=j
#         list_rows.append(list_row)
# print(list_rows)
# Out:
# [{'CART_MEMBER': 5, 'CART_NO': 5, 'CART_PROD': 5, 'CART_QTY': 5}, {'CART_MEMBER': 5, 'CART_NO': 5, 'CART_PROD': 5, 'CART_QTY': 5}, {'CART_MEMBER': 5, 'CART_NO': 5, 'CART_PROD': 5, 'CART_QTY': 5}, {'CART_MEMBER': 5, 'CART_NO': 5, 'CART_PROD': 5, 'CART_QTY': 5}, {'CART_MEMBER': 5, 'CART_NO': 5, 'CART_PROD': 5, 'CART_QTY': 5}, {'CART_MEMBER': 5, 'CART_NO': 5, 'CART_PROD': 5, 'CART_QTY': 5}, {'CART_MEMBER': 5, 'CART_NO': 5, 'CART_PROD': 5, 'CART_QTY': 5}, {'CART_MEMBER': 5, 'CART_NO': 5, 'CART_PROD': 5, 'CART_QTY': 5}, {'CART_MEMBER': 5, 'CART_NO': 5, 'CART_PROD': 5, 'CART_QTY': 5}, {'CART_MEMBER': 5, 'CART_NO': 5, 'CART_PROD': 5, 'CART_QTY': 5}, {'CART_MEMBER': 5, 'CART_NO': 5, 'CART_PROD': 5, 'CART_QTY': 5}, {'CART_MEMBER': 5, 'CART_NO': 5, 'CART_PROD': 5, 'CART_QTY': 5}, {'CART_MEMBER': 5, 'CART_NO': 5, 'CART_PROD': 5, 'CART_QTY': 5}, {'CART_MEMBER': 5, 'CART_NO': 5, 'CART_PROD': 5, 'CART_QTY': 5}, {'CART_MEMBER': 5, 'CART_NO': 5, 'CART_PROD': 5, 'CART_QTY': 5}, {'CART_MEMBER': 5, 'CA
# ...

# %%
list_row=[]

# 풀어헤치기
for cols in rowsb:
    dict_col={}
    for i in range(0,len(cols),1):
        dict_col[col[i]]=cols[i]
        # print("key[{}]/value[{}]".format(col[i],cols[i]))
    list_row.append(dict_col)

list_row
# 이 결과가 objects.all이 던져주는 값과 같음
# Out:
# [{'CART_MEMBER': 'r001',
#   'CART_NO': '2005071100002',
#   'CART_PROD': 'P101000006',
#   'CART_QTY': 20},
#  {'CART_MEMBER': 'i001',
#   'CART_NO': '2005071900001',
#   'CART_PROD': 'P102000001',
#   'CART_QTY': 5},
#  {'CART_MEMBER': 'i001',
#   'CART_NO': '2005071900001',
#   'CART_PROD': 'P102000002',
#   'CART_QTY': 2},
#  {'CART_MEMBER': 'u001',
#   'CART_NO': '2005071900002',
#   'CART_PROD': 'P102000004',
#   'CART_QTY': 4},
#  {'CART_MEMBER': 'j001',
#   'CART_NO': '2005072800001',
#   'CART_PROD': 'P102000006',
#   'CART_QTY': 16},
#  {'CART_MEMBER': 'j001',
#   'CART_NO': '2005072800001',
#   'CART_PROD': 'P102000003',
#   'CART_QTY': 3},
#  {'CART_MEMBER': 'q001',
#   'CART_NO': '2005072800002',
#   'CART_PROD': 'P102000004',
#   'CART_QTY': 4},
#  {'CART_MEMBER': 'q001',
#   'CART_NO': '2005072800002',
#   'CART_PROD': 'P102000005',
#   'CART_QTY': 5},
#  {'CART_MEMBER': 'c001',
#   'CART_NO': '2005072800003',
#   'CART_PROD': 'P301000003',
#   'CART_QTY': 2},
# ...

# %%
cursor.close()
conn.close()
